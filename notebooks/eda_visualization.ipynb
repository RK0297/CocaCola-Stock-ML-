# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
data_path = os.path.join("..", "data", "coca_cola_stock_engineered.csv")
data = pd.read_csv(data_path)

# %%
data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Date', inplace=True)

# %%
print("🔍 Summary Statistics:\n")
print(data.describe())
# Out:
# 🔍 Summary Statistics:
#
#                                 Date        Close         High          Low  \
# count                           2215  2215.000000  2215.000000  2215.000000
# mean   2019-08-06 07:49:22.889390592    42.370852    42.662092    42.074685
# min              2015-03-16 00:00:00    27.698980    28.086046    26.656355
# 25%              2017-05-24 12:00:00    34.197054    34.413326    33.976473
# 50%              2019-08-07 00:00:00    40.305603    40.649247    39.955898
# 75%              2021-10-16 12:00:00    50.157209    50.471635    49.893844
# max              2023-12-29 00:00:00    60.082428    60.980799    59.852175
# std                              NaN     9.412216     9.488300     9.330010
#
#               Open        Volume        MA_20        MA_50  Daily_Return  \
# count  2215.000000  2.215000e+03  2215.000000  2215.000000   2215.000000
# mean     42.375083  1.410882e+07    42.258132    42.088568      0.000369
# ...

# %%
# 5.2 📈 Line Chart: Close + MA_20 + MA_50
plt.figure(figsize=(14, 6))
plt.plot(data['Date'], data['Close'], label='Close', linewidth=2)
plt.plot(data['Date'], data['MA_20'], label='MA 20', linestyle='--')
plt.plot(data['Date'], data['MA_50'], label='MA 50', linestyle='--')
plt.title("Coca-Cola Closing Price with 20 & 50-Day Moving Averages")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# 5.3 🔥 Correlation Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(data.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap of Coca-Cola Stock Features")
plt.tight_layout()
plt.show()
